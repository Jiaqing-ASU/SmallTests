# %%
import matplotlib.pyplot as plt
import numpy as np

fontsize=58
s_fontsize=56

plt.figure(figsize=(34,8))
# fig, ax = plt.subplots(figsize=(34,8), dpi=100, constrained_layout=True)                                  
my_x_ticks = np.arange(2, 7, 1)
plt.xticks(my_x_ticks, fontsize=s_fontsize)
plt.yticks(fontsize=s_fontsize)

x = [2,3,4,6]
k1 = [191,350,506,720]
k2 = [175,262,381,513]
k3 = [430,1112,1474,2209]
k4 = [425,639,962,1398]
plt.plot(x,k1,'s-',color = '#e41a1c',label="SSD w/o dedup", linewidth=4)
plt.plot(x,k2,'s-',color = '#377eb8',label="SSD w/ dedup & optimized caching", linewidth=4)
plt.plot(x,k3,'o-',color = '#4daf4a',label="HDD w/o dedup", linewidth=4)
plt.plot(x,k4,'o-',color = '#984ea3',label="HDD w/ dedup & optimized caching", linewidth=4)
# for a,b in zip(x,k1):
#     plt.text(a, b+10, '%d' % b, ha='center', va= 'bottom',fontsize=11)
# for a,b in zip(x,k2):
#     plt.text(a, b-10, '%d' % b, ha='center', va= 'top',fontsize=11)
# for a,b in zip(x,k3):
#     plt.text(a, b+10, '%d' % b, ha='center', va= 'bottom',fontsize=11)
# for a,b in zip(x,k4):
#     plt.text(a, b-10, '%d' % b, ha='center', va= 'top',fontsize=11)
plt.xlabel("numbers of models", fontsize=fontsize)
plt.ylabel("seconds", fontsize=fontsize)
# plt.legend(loc=(0.01,0.63), fontsize=s_fontsize-12)
# plt.show()

plt.savefig('table-1-visual.pdf',dpi=100,format='pdf', bbox_inches='tight')
