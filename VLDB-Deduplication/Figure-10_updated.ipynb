# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib.ticker import FormatStrFormatter

fontsize=58
s_fontsize=56

fig, ax = plt.subplots(figsize=(34,8), dpi=100, constrained_layout=True)
my_x_ticks = np.arange(8, 16, 1)
plt.xticks(my_x_ticks, fontsize=s_fontsize)
plt.yticks(fontsize=s_fontsize)

x = [8,10,15]
k1 = [675,655,646]
k2 = [595,572,427]
k3 = [557,540,426]
k4 = [1815,1815,1675]
k5 = [1686,1515,1091]
k6 = [1620,1467,1085]

# plt.plot(x,k1,'s-',color = 'b',label="SSD w/o dedup")
# plt.plot(x,k2,'s-',color = 'g',label="SSD w/ dedup")
# plt.plot(x,k3,'s-',color = 'k',label="SSD w/ dedup & optimized caching")

# plt.plot(x,k4,'o-',color = 'm',label="HDD w/o dedup")
# plt.plot(x,k5,'o-',color = 'y',label="HDD w/ dedup")
# plt.plot(x,k6,'o-',color = 'r',label="HDD w/ dedup & optimized caching")

plt.plot(x,k1,'s-',color = '#e41a1c',label="SSD w/o dedup", linewidth=4)
plt.plot(x,k2,'s-',color = '#ff7f00',label="SSD w/ dedup", linewidth=4)
plt.plot(x,k3,'s-',color = '#377eb8',label="SSD w/ dedup & optimized caching  aaaa", linewidth=4)

plt.plot(x,k4,'o-',color = '#4daf4a',label="HDD w/o dedup", linewidth=4)
plt.plot(x,k5,'o-',color = '#a65628',label="HDD w/ dedup", linewidth=4)
plt.plot(x,k6,'o-',color = '#984ea3',label="HDD w/ dedup & optimized caching", linewidth=4)

# for a,b in zip(x,k1):
#     plt.text(a, b+20, '%d' % b, ha='center', va= 'bottom',fontsize=11)
# for a,b in zip(x,k2):
#     plt.text(a, b+60, '%d' % b, ha='center', va= 'top',fontsize=11)
# for a,b in zip(x,k3):
#     plt.text(a, b-100, '%d' % b, ha='center', va= 'bottom',fontsize=11)
# for a,b in zip(x,k4):
#     plt.text(a, b+40, '%d' % b, ha='center', va= 'top',fontsize=11)
# for a,b in zip(x,k5):
#     plt.text(a, b+20, '%d' % b, ha='center', va= 'bottom',fontsize=11)
# for a,b in zip(x,k6):
#     plt.text(a, b+40, '%d' % b, ha='center', va= 'top',fontsize=11)

plt.xlabel("buffer pool size (GB)", fontsize=fontsize)
plt.ylabel("seconds", fontsize=fontsize)

y_major = matplotlib.ticker.LogLocator(base=10, numticks=50)
ax.yaxis.set_minor_locator(y_major)
plt.yticks([400,600,800,1000,1200,1400,1600,1800])
plt.tick_params(axis='y', which='minor')
ax.yaxis.set_major_formatter(FormatStrFormatter("%.0f"))
ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))

# plt.legend(loc=(0,-0.8),fontsize=s_fontsize-2)
plt.show()

fig.savefig('table-6-visual.pdf',dpi=100,format='pdf', bbox_inches='tight')
