# %%
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.ticker import FormatStrFormatter
import numpy as np

plt.figure(figsize=(8,12))
fig, ax = plt.subplots()
my_x_ticks = np.arange(8, 16, 1)
plt.xticks(my_x_ticks)

x = [8,10,15]
k1 = [786,762,720]
k2 = [710,594,513]
k3 = [638,580,513]
k4 = [8120,2264,2209]
k5 = [4921,1435,1398]
k6 = [1720,1435,1398]

plt.plot(x,k1,'s-',color = 'b',label="SSD w/o dedup")
plt.plot(x,k2,'s-',color = 'g',label="SSD w/ dedup")
plt.plot(x,k3,'s-',color = 'k',label="SSD w/ dedup & optimized caching")

plt.plot(x,k4,'o-',color = 'm',label="HDD w/o dedup")
plt.plot(x,k5,'o-',color = 'y',label="HDD w/ dedup")
plt.plot(x,k6,'o-',color = 'r',label="HDD w/ dedup & optimized caching")

for a,b in zip(x,k1):
    plt.text(a, b+100, '%d' % b, ha='center', va= 'bottom',fontsize=9)
for a,b in zip(x,k2):
    plt.text(a, b+100, '%d' % b, ha='center', va= 'top',fontsize=9)
for a,b in zip(x,k3):
    plt.text(a, b-100, '%d' % b, ha='center', va= 'bottom',fontsize=9)
for a,b in zip(x,k4):
    plt.text(a, b+100, '%d' % b, ha='center', va= 'top',fontsize=9)
for a,b in zip(x,k5):
    plt.text(a, b+100, '%d' % b, ha='center', va= 'bottom',fontsize=9)
for a,b in zip(x,k6):
    plt.text(a, b+100, '%d' % b, ha='center', va= 'top',fontsize=9)

plt.xlabel("buffer pool size (GB)")
plt.ylabel("seconds")
plt.yscale('log')
y_major = matplotlib.ticker.LogLocator(base=10, numticks=50)
ax.yaxis.set_minor_locator(y_major)
plt.yticks([500,750,1000,1500,2500,5000,7500,10000])
plt.tick_params(axis='y', which='minor')
ax.yaxis.set_major_formatter(FormatStrFormatter("%.0f"))
ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))

plt.legend(loc=(1.05,0))
plt.show()

fig.savefig('figure-2.pdf',dpi=600,format='pdf')
