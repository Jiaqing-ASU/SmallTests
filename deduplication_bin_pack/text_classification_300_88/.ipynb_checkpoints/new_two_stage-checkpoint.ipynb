# %%
import numpy as np
import sys
from numpy.lib.arraysetops import unique
from bin_pack import *
import uuid
import hashlib
import timeit
import itertools

ll0 = []
for i in range(7):
    thistuple = ('A',i)
    ll0.append(thistuple)
for i in range(80):
    thistuple = ('B',i)
    ll0.append(thistuple)
for i in range(10):
    thistuple = ('C',i)
    ll0.append(thistuple)
for i in range(7):
    thistuple = ('D',i)
    ll0.append(thistuple)
for i in range(43):
    thistuple = ('F',i)
    ll0.append(thistuple)
for i in range(10):
    thistuple = ('H',i)
    ll0.append(thistuple)
for i in range(76):
    thistuple = ('J',i)
    ll0.append(thistuple)
    
ll1 = []
for i in range(7):
    thistuple = ('A',i)
    ll1.append(thistuple)
for i in range(80):
    thistuple = ('B',i)
    ll1.append(thistuple)
for i in range(10):
    thistuple = ('C',i)
    ll1.append(thistuple)
for i in range(8):
    thistuple = ('E',i)
    ll1.append(thistuple)
for i in range(43):
    thistuple = ('F',i)
    ll1.append(thistuple)
for i in range(1):
    thistuple = ('G',i)
    ll1.append(thistuple)
for i in range(64):
    thistuple = ('I',i)
    ll1.append(thistuple)
for i in range(10):
    thistuple = ('K',i)
    ll1.append(thistuple)

ll2 = []
for i in range(7):
    thistuple = ('A',i)
    ll2.append(thistuple)
for i in range(80):
    thistuple = ('B',i)
    ll2.append(thistuple)
for i in range(7):
    thistuple = ('D',i)
    ll2.append(thistuple)
for i in range(8):
    thistuple = ('E',i)
    ll2.append(thistuple)
for i in range(1):
    thistuple = ('G',i)
    ll2.append(thistuple)
for i in range(32):
    thistuple = ('L',i)
    ll2.append(thistuple)
    
ll3 = []
for i in range(7):
    thistuple = ('A',i)
    ll3.append(thistuple)
for i in range(80):
    thistuple = ('B',i)
    ll3.append(thistuple)
for i in range(10):
    thistuple = ('C',i)
    ll3.append(thistuple)
for i in range(7):
    thistuple = ('D',i)
    ll3.append(thistuple)
for i in range(8):
    thistuple = ('E',i)
    ll3.append(thistuple)
for i in range(43):
    thistuple = ('F',i)
    ll3.append(thistuple)
for i in range(1):
    thistuple = ('G',i)
    ll3.append(thistuple)
for i in range(10):
    thistuple = ('H',i)
    ll3.append(thistuple)
for i in range(64):
    thistuple = ('I',i)
    ll3.append(thistuple)
for i in range(4):
    thistuple = ('M',i)
    ll3.append(thistuple)

ll4 = []
for i in range(7):
    thistuple = ('A',i)
    ll4.append(thistuple)
for i in range(10):
    thistuple = ('C',i)
    ll4.append(thistuple)
for i in range(7):
    thistuple = ('D',i)
    ll4.append(thistuple)
for i in range(8):
    thistuple = ('E',i)
    ll4.append(thistuple)
for i in range(15):
    thistuple = ('N',i)
    ll4.append(thistuple)

list_of_tensors = [ll0,ll1,ll2,ll3,ll4]

blocks_in_page = 8
P = set()
start = timeit.default_timer()
P, tensor_page_mapping = bin_pack_greedy(list_of_tensors, blocks_in_page)
stop = timeit.default_timer()
print('Time: ', stop - start) 
L = list(P)
print(L[0].numBins)
block_page_list = L[0].p_i_j
